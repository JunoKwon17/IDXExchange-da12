# %%
import pandas as pd
df_listed = pd.read_csv("data/CRMLSListing202602.csv")
df_sold = pd.read_csv("data/CRMLSSold202602.csv")

# %%
df_listed.head()
# Out:
#    OriginalListPrice  ListingKey   CloseDate  ClosePrice ListAgentFirstName  \
# 0           599000.0  1155878924         NaN         NaN             Rhonda
# 1           699000.0  1155878603         NaN         NaN            Frances
# 2          1250000.0  1155878531  2026-03-24   1250000.0             Marcel
# 3            27000.0  1155877325         NaN         NaN            Georgie
# 4           699000.0  1155873898         NaN         NaN               Ryan
#
#   ListAgentLastName   Latitude   Longitude       UnparsedAddress  \
# 0          Cudeback  33.846885 -118.189492    309 E Silva Street
# 1            Mouser  33.587219 -117.177790  27636 Brentstone Way
# 2             Bonee  33.162238 -117.260161    5086 Corinthia Way
# 3            Fenton  33.605898 -117.893620          203 Sapphire
# 4             Caron  32.696978 -117.009878        8773 Leigh Ave
#
#        PropertyType  ...  MainLevelBedrooms  NewConstructionYN  GarageSpaces  \
# ...

# %%
df_sold.head()
# Out:
#            BuyerAgentAOR           ListAgentAOR     Flooring ViewYN  \
# 0            ContraCosta                BayEast          NaN    NaN
# 1           OrangeCounty           OrangeCounty  Carpet,Tile  False
# 2  BeverlyHillsGreaterLa  BeverlyHillsGreaterLa         Wood  False
# 3               SanDiego               SanDiego          NaN    NaN
# 4                Newport                Newport          NaN  False
#
#   WaterfrontYN BasementYN PoolPrivateYN  OriginalListPrice  ListingKey  \
# 0          NaN        NaN           NaN          1580000.0  1155696412
# 1          NaN        NaN         False          1100000.0  1155620121
# 2          NaN        NaN         False           999000.0  1155350576
# 3          NaN        NaN           NaN          1650000.0  1155221012
# 4          NaN        NaN         False           525000.0  1155192177
#
#     CloseDate  ...  MainLevelBedrooms NewConstructionYN GarageSpaces  \
# ...
